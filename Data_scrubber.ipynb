# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
from Datascrubber import Datacleaning
data_cleaner = Datacleaning()

# %%
test = pd.read_csv('H:\Big_Data_Mining\Practicals\Test.csv')
test
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDW58       20.750          Low Fat         0.007565
# 1              FDW14        8.300              reg         0.038428
# 2              NCN55       14.600          Low Fat         0.099575
# 3              FDQ58        7.315          Low Fat         0.015388
# 4              FDY38          NaN          Regular         0.118599
# ...              ...          ...              ...              ...
# 5676           FDB58       10.500          Regular         0.013496
# 5677           FDD47        7.600          Regular         0.142991
# 5678           NCO17       10.000          Low Fat         0.073529
# 5679           FDJ26       15.300          Regular         0.000000
# 5680           FDU37        9.500          Regular         0.104720
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0            Snack Foods  107.8622            OUT049
# ...

# %%
data_cleaner.read_data('H:\Big_Data_Mining\Practicals\Test.csv')
# Out:
# Data Description:
#
# The file Test has 5681 Rows and 11 Columns
#
# Categorical Columns(7): Item_Identifier, Item_Fat_Content, Item_Type, Outlet_Identifier, Outlet_Size, Outlet_Location_Type, Outlet_Type
# Continuous Columns(4): Item_Weight, Item_Visibility, Item_MRP, Outlet_Establishment_Year
#
# Missing Values:2593
#
# Details :
# - Item_Identifier: 0
# - Item_Weight: 976
# - Item_Fat_Content: 0
# - Item_Visibility: 2
# - Item_Type: 0
# - Item_MRP: 0
# - Outlet_Identifier: 0
# - Outlet_Establishment_Year: 2
# - Outlet_Size: 1606
# - Outlet_Location_Type: 2
# - Outlet_Type: 5
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDW58       20.750          Low Fat         0.007565  Snack Foods
# 1           FDW14        8.300              reg         0.038428        Dairy
# 2           NCN55       14.600          Low Fat         0.099575       Others
# 3           FDQ58        7.315          Low Fat         0.015388  Snack Foods
# ...

# %%
data_cleaner.columns()
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type'],
#       dtype='object')

# %%
data_cleaner.summary()
# Out:
#        Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# count             5681  4705.000000             5681      5679.000000
# unique            1543          NaN                5              NaN
# top              DRF48          NaN          Low Fat              NaN
# freq                 8          NaN             3396              NaN
# mean               NaN    12.695633              NaN         0.065694
# std                NaN     4.664849              NaN         0.051258
# min                NaN     4.555000              NaN         0.000000
# 25%                NaN     8.645000              NaN         0.027045
# 50%                NaN    12.500000              NaN         0.054167
# 75%                NaN    16.700000              NaN         0.093464
# max                NaN    21.350000              NaN         0.323637
#
#           Item_Type     Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# ...

# %% [markdown]
# ## Dealing with missing values

# %%
data_cleaner.missing_values()
# Out:
# Item_Identifier                 0
# Item_Weight                   976
# Item_Fat_Content                0
# Item_Visibility                 2
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       2
# Outlet_Size                  1606
# Outlet_Location_Type            2
# Outlet_Type                     5
# dtype: int64

# %%
data_cleaner.col_missing_value('Outlet_Size')
# Out:
# 1606

# %%
data_cleaner.cat_cols()
# Out:
#   Item_Identifier Item_Fat_Content    Item_Type Outlet_Identifier Outlet_Size  \
# 0           FDW58          Low Fat  Snack Foods            OUT049      Medium
# 1           FDW14              reg        Dairy            OUT017         NaN
# 2           NCN55          Low Fat       Others            OUT010         NaN
# 3           FDQ58          Low Fat  Snack Foods            OUT017         NaN
# 4           FDY38          Regular        Dairy            OUT027      Medium
#
#   Outlet_Location_Type        Outlet_Type
# 0               Tier 1  Supermarket Type1
# 1               Tier 2  Supermarket Type1
# 2               Tier 3      Grocery Store
# 3               Tier 2  Supermarket Type1
# 4               Tier 3  Supermarket Type3

# %%
data_cleaner.cont_cols()
# Out:
#    Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year
# 0       20.750         0.007565  107.8622                     1999.0
# 1        8.300         0.038428   87.3198                     2007.0
# 2       14.600         0.099575  241.7538                     1998.0
# 3        7.315         0.015388  155.0340                     2007.0
# 4          NaN         0.118599  234.2300                     1985.0

# %%
data_cleaner.distributions()
# Out:
# c:\Users\irfan\AppData\Local\Programs\Python\Python311\Lib\site-packages\Datascrubber\datacleaning.py:215: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=rotation_angle)
# c:\Users\irfan\AppData\Local\Programs\Python\Python311\Lib\site-packages\Datascrubber\datacleaning.py:215: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=rotation_angle)
# c:\Users\irfan\AppData\Local\Programs\Python\Python311\Lib\site-packages\Datascrubber\datacleaning.py:215: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=rotation_angle)
# ...

# %% [markdown]
# - Dealing wit missing values

# %%
data_cleaner.remove_missingvalues()
# Out:
# c:\Users\irfan\AppData\Local\Programs\Python\Python311\Lib\site-packages\Datascrubber\datacleaning.py:304: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   self.dataframe[col_name].fillna(
# c:\Users\irfan\AppData\Local\Programs\Python\Python311\Lib\site-packages\Datascrubber\datacleaning.py:319: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
data_cleaner.missing_values()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# dtype: int64

# %%
data_cleaner.outliers()

# %%
data_cleaner.outliers_single('Item_Visibility')

# %%
## Remmoving outliers
data_cleaner.remove_outliers()  # For all the columns

# %%
## For a single column
data_cleaner.remove_outliers_single('Item_Visibility')

# %%
data_cleaner.outliers_single('Item_Visibility')

# %%
data_cleaner.cont_cols().columns
# Out:
# Index(['Item_Weight', 'Item_Visibility', 'Item_MRP',
#        'Outlet_Establishment_Year'],
#       dtype='object')

# %%
data_cleaner.cont_to_cont('Item_MRP','Item_Visibility')
# Out:
# The correlation between Item_MRP and Item_Visibility is: -0.01113080494148439

# %%
data_cleaner.cont_to_cat('Item_Visibility','Item_Type')
# Out:
# Item_Type is correlated with Item_Visibility

# %%
data_cleaner.cont_to_cat('Item_Fat_Content','Item_MRP')
# Out:
# Item_Fat_Content is not correlated with Item_MRP

# %%
data_cleaner.cat_to_cat('Item_Fat_Content','Item_Type')
# Out:
# Chi_square value: 1135.7999939106282
# p value: 2.0617254970739506e-198
# degrees of freedom: 60
# Item_Fat_Content is correlated with Item_Type

# %%
data_cleaner.corr_matrix()

# %%
data_cleaner.cat_cols().columns
# Out:
# Index(['Item_Identifier', 'Item_Fat_Content', 'Item_Type', 'Outlet_Identifier',
#        'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type'],
#       dtype='object')

# %%
data_cleaner.cont_to_cat('Item_MRP',['Item_Identifier','Item_Fat_Content', 'Item_Type', 'Outlet_Identifier','Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type'])
# Out:
# Item_Identifier is correlated with Item_MRP
# Item_Fat_Content is not correlated with Item_MRP
# Item_Type is correlated with Item_MRP
# Outlet_Identifier is not correlated with Item_MRP
# Outlet_Size is not correlated with Item_MRP
# Outlet_Location_Type is not correlated with Item_MRP
# Outlet_Type is not correlated with Item_MRP

# %%
data_cleaner.cont_to_cont(['Item_MRP', 'Outlet_Establishment_Year'],['Item_Visibility', 'Item_Weight'])
# Out:
# The correlation between Item_MRP and Item_Visibility is: -0.01113080494148439
# The correlation between Item_MRP and Item_Weight is: 0.045256940140919626
# The correlation between Outlet_Establishment_Year and Item_Visibility is: -0.08764135482746653
# The correlation between Outlet_Establishment_Year and Item_Weight is: 0.013834697838876274
